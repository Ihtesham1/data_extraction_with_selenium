# %%
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\Ihtesham\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p70')

# %%
userid_element = driver.find_elements_by_xpath('//*[@id="Comment_1736202"]/div/div[2]/div[1]/span[1]/a[2]')[0]
user_id = userid_element.text

# %%
user_date = driver.find_elements_by_xpath('//*[@id="Comment_1736202"]/div/div[2]/div[2]/span[1]/a/time')[0]
date = user_date.get_attribute('title')

# %%
user_message = driver.find_elements_by_xpath('//*[@id="Comment_1736202"]/div/div[3]/div/div[1]')[0]
comment = user_message.text

# %%
comments = pd.DataFrame(columns = ['Date','user_id','comments']) 
ids = driver.find_elements_by_xpath("//*[contains(@id,'Comment_')]")
comment_ids = []

for i in ids:
    comment_ids.append(i.get_attribute('id'))
    
for x in comment_ids:
    #Extract dates from each user on a page
    user_date = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[2]/span[1]/a/time')[0]
    date = user_date.get_attribute('title')

    #Extract user ids from each user on a page
    userid_element = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[1]/span[1]/a[2]')[0]
    userid = userid_element.text

    #Extract Message for each user on a page
    user_message = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[3]/div/div[1]')[0]
    comment = user_message.text
                                   
    #Adding date, userid and comment for each user in a dataframe    
    comments.loc[len(comments)] = [date,userid,comment]

# %%
comments
# Out:
#                      Date        user_id  \
# 0     June 9, 2005 6:26PM     frisconick
# 1     June 9, 2005 9:39PM        jsamson
# 2    June 10, 2005 6:43AM        jrock65
# 3   June 10, 2005 10:54AM  blueguydotcom
# 4   June 11, 2005 11:02AM        draknad
# 5    June 11, 2005 1:47PM     frisconick
# 6    June 11, 2005 3:23PM      jamesspot
# 7    June 11, 2005 3:35PM     frisconick
# 8    June 11, 2005 5:57PM  blueguydotcom
# 9    June 11, 2005 6:14PM      kdshapiro
# 10  June 11, 2005 10:21PM        jsamson
# 11  June 11, 2005 11:30PM     frisconick
# 12   June 12, 2005 4:55AM      kdshapiro
# 13   June 12, 2005 8:39AM        lmacmil
# 14   June 12, 2005 8:47AM        draknad
# 15  June 12, 2005 10:23AM        jrock65
# 16  June 12, 2005 10:33AM        jrock65
# 17  June 12, 2005 10:46AM     frisconick
# 18  June 12, 2005 12:41PM      kdshapiro
# 19   June 12, 2005 1:35PM         irnmdn
# 20   June 12, 2005 1:56PM      kdshapiro
# 21   June 12, 2005 3:36PM        lmacmil
# ...
